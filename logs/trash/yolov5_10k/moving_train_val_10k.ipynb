# %% [markdown]
# ##### in this file i am going to write a code to move the files from "C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k"
# #### to respective folder of train, val, test

# %%
import os

# %% [markdown]
# ## for 100k images

# %%
# read the files of the train folder and move them accordingly 
train_txt = r"C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k\train_names.txt"
val_txt =r"C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k\val_names.txt"

# %%
import os
import shutil

# # Path of the folder containing the files to move
# folder_path = '/path/to/folder'

# # Path of the text file containing the names of the files to move
# filelist_path = '/path/to/file.txt'

# # Path of the destination folder to move the files
# destination_path = '/path/to/destination'

# source_folder = r"C:\Users\SIU856522160\Downloads\export_folder\images\val"
source_folder = r"C:\Users\SIU856522160\Downloads\export_floder_10k\10k_c\images\val"
train_destination_folder = r"C:\Users\SIU856522160\Downloads\export_floder_10k\images\train"
# file_list_file = r"C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k\train_names.txt"
file_list_file = r"C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k\train_names.txt"

# Open the filelist text file and read the names of the files to move
with open(file_list_file, 'r') as f:
    files_to_move = f.read().splitlines()

# Loop through the list of files and check if they exist in the folder
for filename in files_to_move:
    filepath = os.path.join(source_folder, filename)
    if os.path.exists(filepath):
        # If the file exists, move it to the destination folder
        shutil.move(filepath, os.path.join(train_destination_folder, filename))
        print(f'Moved {filename} to {train_destination_folder}')
    else:
        # If the file does not exist, skip it
        print(f'Skipping {filename} (file not found)')
# Out:
# Skipping 0004a4c0-d4dff0ad.jpg (file not found)
# Skipping 00054602-3bf57337.jpg (file not found)
# Skipping 00067cfb-e535423e.jpg (file not found)
# Skipping 00091078-59817bb0.jpg (file not found)
# Skipping 0010bf16-a457685b.jpg (file not found)
# Skipping 001b428f-059bac33.jpg (file not found)
# Skipping 001c2a14-c7138401.jpg (file not found)
# Skipping 0024b742-acbefa1a.jpg (file not found)
# Skipping 0027eed2-09c90000.jpg (file not found)
# Skipping 0027eed2-09c90001.jpg (file not found)
# Skipping 0027eed2-60fb0001.jpg (file not found)
# Skipping 0027eed2-815a0000.jpg (file not found)
# Skipping 0027eed2-815a0001.jpg (file not found)
# Skipping 0027eed2-a6630000.jpg (file not found)
# Skipping 0027eed2-a6630001.jpg (file not found)
# Skipping 002a3213-ab7f6730.jpg (file not found)
# Skipping 002bf392-acddbad2.jpg (file not found)
# Skipping 002d467e-00000000.jpg (file not found)
# Skipping 003571f2-f2848ebd.jpg (file not found)
# Skipping 003ddde7-36ee8299.jpg (file not found)
# ...

# %%
import shutil
source_folder = r"C:\Users\SIU856522160\Downloads\export_floder_10k\images\val"
train_destination_folder = r"C:\Users\SIU856522160\Downloads\export_floder_10k\images\train"
file_list_file = r"C:\Users\SIU856522160\Downloads\final repo\yolov5_10k\10k\train_names.txt"

# Read the list of file names from the text file
with open(file_list_file, "r") as file:
    file_list = [line.strip() for line in file.readlines()]

# Move each file from the source folder to the destination folder
for file_name in file_list:
    source_file_path = source_folder + "\\" + file_name
    destination_file_path = train_destination_folder + "\\" + file_name
    shutil.move(source_file_path, train_destination_folder)
    
# Replace the /path/to/source/folder, /path/to/destination/folder, and /path/to/file/list.txt with the actual paths of your source folder, destination folder, and text file respectively.
# Note that the file names in the text file should be the names of the files in the source folder, not the full paths.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\SIU856522160\Anaconda3\envs\venv\lib\shutil.py:816, in move(src, dst, copy_function)
#     815 try:
# --> 816     os.rename(src, real_dst)
#     817 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\SIU856522160\\Downloads\\export_floder_10k\\images\\val\\0004a4c0-d4dff0ad.jpg' -> 'C:\\Users\\SIU856522160\\Downloads\\export_floder_10k\\images\\train\\0004a4c0-d4dff0ad.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 14
#      12     source_file_path = source_folder + "\\" + file_name
#      13     destination_file_path = train_destination_folder + "\\" + file_name
# ---> 14     shutil.move(source_file_path, train_destination_folder)
# ...

# %%
import shutil

source_folder = r"C:\Users\SIU856522160\Downloads\export_folder\images\val"
# source_folder = r"C:\Users\SIU856522160\Downloads\export_folder\images_after_moving"
train_destination_folder = r"C:\Users\SIU856522160\Downloads\export_folder\images_after_moving\test"
file_list_file = r"C:\Users\SIU856522160\Downloads\final repo\yolov5\test_names.txt"

# Read the list of file names from the text file
with open(file_list_file, "r") as file:
    file_list = [line.strip() for line in file.readlines()]

# Move each file from the source folder to the destination folder
for file_name in file_list:
    source_file_path = source_folder + "/" + file_name
    destination_file_path = train_destination_folder + "/" + file_name
    shutil.move(source_file_path, train_destination_folder)
    
# Replace the /path/to/source/folder, /path/to/destination/folder, and /path/to/file/list.txt with the actual paths of your source folder, destination folder, and text file respectively.
# Note that the file names in the text file should be the names of the files in the source folder, not the full paths.

# %%
200000-139863
# Out:
# 60137

# %% [markdown]
# # for 10k images

# %%
import os
import shutil

# # Path of the folder containing the files to move

# # Path of the text file containing the names of the files to move

# # Path of the destination folder to move the files


folder_path = r"C:\Users\SIU856522160\Downloads\export_folder\images\val"
# source_folder = r"C:\Users\SIU856522160\Downloads\export_folder\images_after_moving"
destination_path = r"C:\Users\SIU856522160\Downloads\export_folder\images_after_moving\train"
filelist_path = r"C:\Users\SIU856522160\Downloads\final repo\yolov5\train_names_txt.txt"

# Open the filelist text file and read the names of the files to move
with open(filelist_path, 'r') as f:
    files_to_move = f.read().splitlines()

# Loop through the list of files and check if they exist in the folder
for filename in files_to_move:
    filepath = os.path.join(folder_path, filename)
    if os.path.exists(filepath):
        # If the file exists, move it to the destination folder
        shutil.move(filepath, os.path.join(destination_path, filename))
        print(f'Moved {filename} to {destination_path}')
    else:
        # If the file does not exist, skip it
        print(f'Skipping {filename} (file not found)')
