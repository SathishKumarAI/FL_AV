# %%
import os

# %%
train_dir_images = r"C:\Users\SIU856522160\Downloads\export_folder\images\val"
filenames_images = os.listdir(train_dir_images)

# %%
filenames_images[1:10]
# Out:
# ['0000f77c-6257be58.txt',
#  '0000f77c-62c2a288.jpg',
#  '0000f77c-62c2a288.txt',
#  '0000f77c-cb820c98.jpg',
#  '0000f77c-cb820c98.txt',
#  '0001542f-5ce3cf52.jpg',
#  '0001542f-5ce3cf52.txt',
#  '0001542f-7c670be8.jpg',
#  '0001542f-7c670be8.txt']

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image file
img = cv2.imread(train_dir_images+os.sep+filenames_images[2])

# Display the image
plt.imshow(img)
plt.show()

# %% [markdown]
# ### reading the .txt file content

# %%
train_dir_txt = r"C:\Users\SIU856522160\Downloads\export_folder\labels\val"
filenames_txt = os.listdir(train_dir_txt)

# %%
filenames_images[2]
# Out:
# '0000f77c-cb820c98.jpg'

# %%
filenames_txt[2]
# Out:
# '0000f77c-cb820c98.txt'

# %%
with open(train_dir_txt+os.sep+filenames_txt[2], 'r') as f:
    print(f.read())
# Out:
# 2 0.477835 0.452577 0.046392 0.068041
# 2 0.554961 0.438144 0.019716 0.043299
# 2 0.579897 0.449485 0.041753 0.057732
# 2 0.634407 0.463918 0.081186 0.115464
# 2 0.663402 0.481443 0.074227 0.129897
# 2 0.753634 0.500000 0.173969 0.212371
# 2 0.942681 0.583093 0.111340 0.329897

# %% [markdown]
# #### verification done
