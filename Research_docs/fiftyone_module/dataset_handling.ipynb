# %% [markdown]
# ##### installation of the fiftyone module in the system at below there is a tutorial that can be helpful to learn https://medium.com/voxel51/exploring-the-berkeley-deep-drive-autonomous-vehicle-dataset-a10eb633b16e

# %%
# %pip install fiftyone

# %%
import fiftyone as fo
import fiftyone.zoo as foz

# The path to the source files that you manually downloaded
dataset_dir = r"C:\Users\SIU856522160\expo_1\bdd100k\\"

# %%
dataset = foz.load_zoo_dataset(
    "bdd100k",
    # split="validation",
    source_dir=dataset_dir,
)
# Out:
# Split 'train' already prepared
# Split 'validation' already prepared
# Split 'test' already prepared
# Loading existing dataset 'bdd100k'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
session = fo.launch_app(dataset)
# Out:
# Could not connect session, trying again in 10 seconds
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 session = fo.launch_app(dataset)
#
# File c:\Users\SIU856522160\Anaconda3\envs\venv\lib\site-packages\fiftyone\core\session\session.py:163, in launch_app(dataset, view, spaces, plots, port, address, remote, desktop, height, auto, config)
#     151 #
#     152 # Note, we always `close_app()` here rather than just calling
#     153 # `session.open()` if a session already exists, because the app may have
#    (...)
#     159 # @todo this can probably be improved
#     160 #
#     161 close_app()
# --> 163 _session = Session(
#     164     dataset=dataset,
#     165     view=view,
#     166     spaces=spaces,
#     167     plots=plots,
#     168     port=port,
#     169     address=address,
#     170     remote=remote,
#     171     desktop=desktop,
# ...

# %%
# View summary info about the dataset
print(dataset)

# Print the first few samples in the dataset
print(dataset.head())
# Out:
# Name:        bdd100k
# Media type:  image
# Num samples: 100000
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:         fiftyone.core.fields.ObjectIdField
#     filepath:   fiftyone.core.fields.StringField
#     tags:       fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     weather:    fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     scene:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     timeofday:  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     detections: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     polylines:  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Polylines)
# [<Sample: {
#     'id': '63e1bd7d5accbec6b815fd45',
#     'media_type': 'image',
# ...
